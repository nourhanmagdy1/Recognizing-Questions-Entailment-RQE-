# %% [markdown]
# # Recognizing Questions Entailment & the type prediction Project

# %% [markdown]
# ## Import Libiraries

# %% [markdown]
# Overleaf link: https://www.overleaf.com/project/62a907c7c720f7abb408c1f1

# %%
! pip install -q Distance
! pip install -q scikit-optimize

# %%
import pandas as pd
from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn import svm
import nltk, re, spacy, scipy
from sklearn.preprocessing import LabelEncoder
from scipy.stats import mannwhitneyu,wilcoxon,ttest_rel,chi2_contingency
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
! pip install -q joblib
import joblib
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer 
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse import hstack
import numpy as np
! pip install -q nltk
import nltk
nltk.download('punkt')
nltk.download('all')

from nltk.tokenize import word_tokenize 
from sklearn.metrics import confusion_matrix, accuracy_score, average_precision_score
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import r2_score

from keras.regularizers import l2
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model

from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform
from keras.layers import Input, Dense, Flatten, GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Multiply, Dropout, Subtract, Add, Conv2D
import tensorflow as tf
import keras
import keras.backend as K
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.layers import Input, Concatenate, Conv2D, Flatten, Dense, Embedding, LSTM
from keras.models import Model
from nltk.internals import find_jars_within_path
from nltk.tag import StanfordPOSTagger
from nltk.tag import StanfordNERTagger
from sklearn import linear_model
from sklearn.metrics import fbeta_score, accuracy_score

from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from skopt import BayesSearchCV

import tensorflow as tf
import keras
import keras.backend as K
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from keras.models import Model

from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform
from keras.layers import Input, Dense, Flatten, GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Multiply, Dropout, Subtract, Add, Conv2D

from keras import backend as K
from sklearn.metrics import roc_auc_score
from tensorflow.keras import regularizers
import os
from lxml import objectify
import pandas as pd
import csv
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import BernoulliNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV,RandomizedSearchCV
from sklearn.model_selection import PredefinedSplit
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from pprint import pprint
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import distance
# !pip install --upgrade
# !pip install strsimpy 
import strsimpy
from strsimpy.levenshtein import Levenshtein
from strsimpy.normalized_levenshtein import NormalizedLevenshtein
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from strsimpy.jaro_winkler import JaroWinkler
from sklearn.metrics import mean_squared_error
import seaborn as sns
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# ERROR: You must give at least one requirement to install (see "pip help install")
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: strsimpy in /usr/local/lib/python3.7/dist-packages (0.2.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Read Data and Select Features
# link for first dataset: https://drive.google.com/file/d/15reIx7kjvGRBCmmFmXqpIKCXcAqrW5nL/view?usp=sharing
#
# link for second dataset: https://drive.google.com/file/d/1jGbmNNwiMzK16V_x30G7HHqe2QBOU25u/view?usp=sharing
#
# Download first data from the first link then enter the bath in df1.
#
# Download secind data from second link and enter the bath in df2.
#
# Then run the whole code.

# %% [markdown]
# ### **For the first data**
# ### Data that will be used to predict the type of question.

# %%
#import train data
df1 = pd.read_csv("/content/drive/MyDrive/med_withCoarse.csv")

# %%
#drop useless features
df_1=df1.drop(columns=['Answer','Qtype-Coarse','Focus'])

# %%
df_1
# Out:
#             Qtype-Fine                                           Question
# 0          information                            What is (are) Aphasia ?
# 1            treatment              What are the treatments for Aphasia ?
# 2              outlook                  What is the outlook for Aphasia ?
# 3             research  what research (or clinical trials) is being do...
# 4          information                             What is (are) Autism ?
# ...                ...                                                ...
# 46851         symptoms           What are the symptoms of Atrial myxoma ?
# 46852  exams and tests                    How to diagnose Atrial myxoma ?
# 46853        treatment        What are the treatments for Atrial myxoma ?
# 46854          outlook            What is the outlook for Atrial myxoma ?
# 46855    complications      What are the complications of Atrial myxoma ?
#
# [46856 rows x 2 columns]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46856 entries, 0 to 46855
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Qtype-Fine  46856 non-null  object
#  1   Question    46856 non-null  object
# dtypes: object(2)
# memory usage: 732.2+ KB

# %%
df_1.describe()
# Out:
#          Qtype-Fine                                Question
# count         46856                                   46856
# unique           39                                   44603
# top     information  What is (are) High Blood Cholesterol ?
# freq           9005                                      19

# %%
df_1.duplicated().sum()
# Out:
# 2253

# %% [markdown]
# ### **For the second data**
# ### Data that will be used to measure rank of entailment between two question.

# %%
df2=pd.read_csv('/content/drive/MyDrive/pair_questions.csv')

# %%
df_2=df2.drop(columns=['ID'])

# %%
df_2.head()
# Out:
#                                           Question_1  \
# 0  What is (are) Polycystic ovary syndrome ? (Als...
# 1  What causes Polycystic ovary syndrome ? (Also ...
# 2                      What causes Noonan syndrome ?
# 3    What are the complications of Noonan syndrome ?
# 4                   How to prevent Noonan syndrome ?
#
#                                          normal_Ques  \
# 0  What are the references with noonan syndrome a...
# 1  What are the references with noonan syndrome a...
# 2  What are the references with noonan syndrome a...
# 3  What are the references with noonan syndrome a...
# 4  What are the references with noonan syndrome a...
#
#                                      scientific_Ques  Judge_score
# 0  What is the relationship between Noonan syndro...  1-Incorrect
# 1  What is the relationship between Noonan syndro...  1-Incorrect
# 2  What is the relationship between Noonan syndro...    2-Related
# 3  What is the relationship between Noonan syndro...    2-Related
# 4  What is the relationship between Noonan syndro...    2-Related

# %%
df_2.describe()
# Out:
#                       Question_1  \
# count                       2479
# unique                      1805
# top     What is (are) Shingles ?
# freq                          15
#
#                                               normal_Ques  \
# count                                                2479
# unique                                                103
# top     My question to you is: what is the reason that...
# freq                                                   45
#
#                                           scientific_Ques  Judge_score
# count                                                2479         2479
# unique                                                103            4
# top     What is the reason that there is so little res...  1-Incorrect
# freq                                                   45         1436

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2479 entries, 0 to 2478
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Question_1       2479 non-null   object
#  1   normal_Ques      2479 non-null   object
#  2   scientific_Ques  2479 non-null   object
#  3   Judge_score      2479 non-null   object
# dtypes: object(4)
# memory usage: 77.6+ KB

# %%
df_2['normal_Ques'][0]
# Out:
# 'What are the references with noonan syndrome and polycystic renal disease'

# %% [markdown]
# ## Data Preprocessing

# %%
def preprocess(corpus, ques_words, cleaning = True, lemmatization = True, remove = True):

    cleaned_corpus = pd.DataFrame()
    for row in corpus:
        dataa = []
        for word in row.split():
          # remove punctuation
            x1 = re.sub(pattern='[^a-zA-Z_]',repl=' ',string=word)
            # convert words to lowecase
            x2 = x1.lower()
            dataa.append(x2)
        cleaned_corpus = cleaned_corpus.append(pd.Series(' '.join(dataa)), ignore_index=True)
    corpus=cleaned_corpus
    corpus.columns = ["entail"]
    #remove stopwords
    if remove == True:
        stop = set(stopwords.words('english'))
        for word in ques_words:
            stop.remove(word)
        corpus = [[x for x in x.split() if x not in stop] for x in corpus["entail"]]
    else :
        corpus = [[x for x in x.split()] for x in corpus]
        # apply lemmatizing to convert to base words
    if lemmatization == True:
        lem = WordNetLemmatizer()
        corpus = [[lem.lemmatize(x, pos = 'v') for x in x] for x in corpus]
    corpus = [' '.join(x) for x in corpus]
    return corpus

# %% [markdown]
# ### First Data cleaninig and preprocessing

# %%
#for the first data
df_1 = df_1.convert_dtypes()
ques = pd.Series(df_1['Question'].tolist()).astype(str)

# %%
# prprocess first data
ques_wor = ['who', 'what', 'when', 'why', 'how', 'which', 'where', 'whom']
df_1['Question'] = preprocess(ques, ques_wor)

# %%
df_1
# Out:
#             Qtype-Fine                                  Question
# 0          information                              what aphasia
# 1            treatment                   what treatments aphasia
# 2              outlook                      what outlook aphasia
# 3             research  what research clinical trials do aphasia
# 4          information                               what autism
# ...                ...                                       ...
# 46851         symptoms               what symptoms atrial myxoma
# 46852  exams and tests                how diagnose atrial myxoma
# 46853        treatment             what treatments atrial myxoma
# 46854          outlook                what outlook atrial myxoma
# 46855    complications          what complications atrial myxoma
#
# [46856 rows x 2 columns]

# %%
#convert to string type
typ_train = pd.Series(df_1['Qtype-Fine'].tolist()).astype(str)

# %%
#remove some special char. from Qtype
typ_train=typ_train.str.translate(str.maketrans({',':' '}))
typ_train=typ_train.str.translate(str.maketrans({'_':' '}))

# %%
# preprocess Qtype
ques_wor_=[]
df_1['Qtype-Fine']=preprocess(typ_train, ques_wor_)

# %%
df_1
# Out:
#           Qtype-Fine                                  Question
# 0        information                              what aphasia
# 1          treatment                   what treatments aphasia
# 2            outlook                      what outlook aphasia
# 3           research  what research clinical trials do aphasia
# 4        information                               what autism
# ...              ...                                       ...
# 46851       symptoms               what symptoms atrial myxoma
# 46852     exams test                how diagnose atrial myxoma
# 46853      treatment             what treatments atrial myxoma
# 46854        outlook                what outlook atrial myxoma
# 46855  complications          what complications atrial myxoma
#
# [46856 rows x 2 columns]

# %% [markdown]
# ### Second data cleaning and preprocessing

# %%
#for second data
df_2= df_2.convert_dtypes()
ques_1 = pd.Series(df_2['Question_1'].tolist()).astype(str)
ques2 = pd.Series(df_2['normal_Ques'].tolist()).astype(str)
ques3 = pd.Series(df_2['scientific_Ques'].tolist()).astype(str)

# %%
#preprocess second data
ques_wor =['who', 'what', 'when', 'why', 'how', 'which', 'where', 'whom']
df_2['Question_1']=preprocess(ques_1, ques_wor)
df_2['normal_Ques']=preprocess(ques2, ques_wor)
df_2['scientific_Ques']=preprocess(ques3, ques_wor)

# %%
df_2
# Out:
#                                              Question_1  \
# 0     what polycystic ovary syndrome also call polyc...
# 1     what cause polycystic ovary syndrome also call...
# 2                            what cause noonan syndrome
# 3                    what complications noonan syndrome
# 4                           how prevent noonan syndrome
# ...                                                 ...
# 2474                       what forget dose glimepiride
# 2475                  what side effect risk glimepiride
# 2476           what case emergency overdose glimepiride
# 2477                  what information know glimepiride
# 2478             what know storage disposal glimepiride
#
#                                             normal_Ques  \
# 0     what reference noonan syndrome polycystic rena...
# 1     what reference noonan syndrome polycystic rena...
# 2     what reference noonan syndrome polycystic rena...
# 3     what reference noonan syndrome polycystic rena...
# 4     what reference noonan syndrome polycystic rena...
# ...                                                 ...
# 2474  please provide glimepiride storage allowable t...
# 2475  please provide glimepiride storage allowable t...
# 2476  please provide glimepiride storage allowable t...
# 2477  please provide glimepiride storage allowable t...
# 2478  please provide glimepiride storage allowable t...
#
#                                         scientific_Ques  Judge_score
# 0     what relationship noonan syndrome polycystic r...  1-Incorrect
# 1     what relationship noonan syndrome polycystic r...  1-Incorrect
# 2     what relationship noonan syndrome polycystic r...    2-Related
# 3     what relationship noonan syndrome polycystic r...    2-Related
# 4     what relationship noonan syndrome polycystic r...    2-Related
# ...                                                 ...          ...
# 2474  define temperature exposure expiration data re...    2-Related
# 2475  define temperature exposure expiration data re...    2-Related
# 2476  define temperature exposure expiration data re...    2-Related
# 2477  define temperature exposure expiration data re...    2-Related
# 2478  define temperature exposure expiration data re...  4-Excellent
#
# [2479 rows x 4 columns]

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### For the first data, Is the ratio of treatment questions in the dataset significantly different from this ratio in the test dataset?

# %%
#check duplicates
df_1.duplicated().sum()
# Out:
# 4119

# %%
# remove duplicates 
df_1=df_1.drop_duplicates()

# %%
# split data into train and test
datatrain,datatest=train_test_split(df_1,test_size=0.3)

# %%
# visualize no. of questions in each type of train data
# %matplotlib inline
GroupedData=datatrain.groupby(by='Qtype-Fine').size()
GroupedData.plot.line()

# %%
# visualize no. of questions in each type of test data
# %matplotlib inline
GroupedData=datatest.groupby(by='Qtype-Fine').size()
GroupedData.plot.line()

# %%
from scipy import stats
datatrain=datatrain[['Qtype-Fine','Question']]
datatest=datatest[['Qtype-Fine','Question']]
train=datatrain[datatrain['Qtype-Fine']=='treatment']
test=datatest[datatest['Qtype-Fine']=='treatment']

# %%
national_table = pd.crosstab(index=train['Qtype-Fine'], columns="count")
minnesota_table = pd.crosstab(index=test['Qtype-Fine'], columns="count")
observed = minnesota_table
national_ratios = national_table/len(datatrain)  # Get population ratios
expected = national_ratios * len(datatest)   # Get expected counts
chi_squared_stat = (((observed-expected)**2)/expected).sum()
print(chi_squared_stat)
# Out:
# col_0
# count    0.133323
# dtype: float64

# %%
p_value = 1 - stats.chi2.cdf(x=chi_squared_stat ,df=38) # Find the p-value
print("P value equal ",p_value)
alpha = 0.05
if p_value > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# P value equal  [1.]
# Same distribution (fail to reject H0)

# %% [markdown]
# The p-value is not less than 0.05 hence, we failed to reject the null hypothesis at a 95% level of confidence. And the two datasets have
# equal median.

# %% [markdown]
# ### For second data exploration

# %%
# check no. of duplicate rows in dataset2 
df_2.duplicated().sum()
# Out:
# 234

# %%
# drop duplicates
df_2=df_2.drop_duplicates()

# %%
# reset index of dataframe
df_2=df_2.reset_index()
df_2=df_2.drop(columns=['index'])

# %% [markdown]
# #### Check if the any two questions have different ranks.

# %%
# check if any duplicate in two questions columns only
df_2.duplicated(subset=['Question_1','normal_Ques']).sum()
# Out:
# 162

# %%
# visualize duplicate questions
da=df_2[df_2.duplicated(subset=['Question_1','normal_Ques'])]
da
# Out:
#                                              Question_1  \
# 11                           what cause noonan syndrome
# 14    noonan syndrome inherit also call male turner ...
# 127   what cause laryngeal nerve damage also call vo...
# 195   what symptoms granulomatosis polyangiitis also...
# 209       what streptococcal infections also call strep
# ...                                                 ...
# 2198  supravalvular aortic stenosis inherit also cal...
# 2213  information rbc count also call erythrocyte co...
# 2216                         information csf cell count
# 2217  information cell count also call thymus derive...
# 2218  information blood count test also call cbc com...
#
#                                             normal_Ques  \
# 11    what reference noonan syndrome polycystic rena...
# 14    what reference noonan syndrome polycystic rena...
# 127   anesthesia give operation severely hurt damage...
# 195   streptococcus infection cause invasive disease...
# 209   streptococcus infection cause invasive disease...
# ...                                                 ...
# 2198                         want know aeortic stenosis
# 2213                   what cause white cells ti uprate
# 2216                   what cause white cells ti uprate
# 2217                   what cause white cells ti uprate
# 2218                   what cause white cells ti uprate
#
#                                         scientific_Ques   Judge_score
# 11    what relationship noonan syndrome polycystic r...  3-Incomplete
# 14    what relationship noonan syndrome polycystic r...  3-Incomplete
# 127   administration anesthesia hip replacement surg...   4-Excellent
# 195     streptococcus infection cause diseases wegeners     2-Related
# 209     streptococcus infection cause diseases wegeners   4-Excellent
# ...                                                 ...           ...
# 2198                      what aortic stenosis anything   4-Excellent
# 2213                   what cause white cells ti uprate     2-Related
# 2216                   what cause white cells ti uprate  3-Incomplete
# 2217                   what cause white cells ti uprate  3-Incomplete
# 2218                   what cause white cells ti uprate  3-Incomplete
#
# [162 rows x 4 columns]

# %%
# display no of questions in each rank
da['Judge_score'].value_counts()
# Out:
# 2-Related       55
# 3-Incomplete    54
# 4-Excellent     53
# Name: Judge_score, dtype: Int64

# %%
# select rows that contain 2 or 3 ranks only
rela_incom=pd.DataFrame()
rela_incom = df_2.loc[df_2['Judge_score'].str.contains("2-Related|3-Incomplete", case=False)]
rela_incom.shape
# Out:
# (832, 4)

# %%
# check the duplicate rows in q1 and q2 only(without duplication in rank)
rela_incom.duplicated(subset=['Question_1','normal_Ques']).sum()
# Out:
# 53

# %%
# select the duplicate rows in q1 and q2 only(without duplication in rank)
rela_inco=rela_incom[rela_incom.duplicated(subset=['Question_1','normal_Ques'])]

# %%
rela_inco=rela_inco.drop(columns='Judge_score')
rela_inco=rela_inco.reset_index()
rela_inco=rela_inco.drop(columns=['index'])
rela_inco
# Out:
#                                            Question_1  \
# 0                          what cause noonan syndrome
# 1   noonan syndrome inherit also call male turner ...
# 2                   how ciprofloxacin use what dosage
# 3                    what side effect risk carvedilol
# 4                     how phentermine use what dosage
# 5   chmp b relate frontotemporal dementia inherit ...
# 6   what cause diarrhea overview also call stool w...
# 7   what diarrhea overview also call stool watery ...
# 8           how amlodipine benazepril use what dosage
# 9                        how atenolol use what dosage
# 10                                 what cause shingle
# 11  how many people affect antiphospholipid syndro...
# 12                  who get simvastatin why prescribe
# 13     safety concern special precautions simvastatin
# 14  what electrical injury also call electrical shock
# 15  information bundle electrography also call bun...
# 16                     how cephalexin use what dosage
# 17  how diagnose arrhythmias also call abnormal he...
# 18  what treatments major depression also call dep...
# 19  what cause hantavirus also call hantavirus pul...
# 20                   who get gabapentin why prescribe
# 21                     how gabapentin use what dosage
# 22      safety concern special precautions gabapentin
# 23                   what side effect risk gabapentin
# 24                     how diclofenac use what dosage
# 25       how prevent trisomy also call patau syndrome
# 26  trisomy inherit also call bartholin patau synd...
# 27  what leg pain also call pain leg ache leg cram...
# 28  what treatments chiggers also call harvest mit...
# 29  what alcohol use safe drink also call beer con...
# 30                                       what shingle
# 31  need see doctor leg pain also call pain leg ac...
# 32  what outlook leg pain also call pain leg ache ...
# 33  information pain relievers also call analgesic...
# 34  what cause thyroid cancer also call tumor thyr...
# 35  how prevent thyroid cancer also call tumor thy...
# 36  information calcium carbonate magnesium overdo...
# 37  information magnesium diet also call diet magn...
# 38                                information calcium
# 39  what osteogenesis imperfecta also call brittle...
# 40  what cervicitis also call cervical inflammatio...
# 41  what cause cervicitis also call cervical infla...
# 42  what symptoms cervicitis also call cervical in...
# 43               what infertility also call sterility
# 44  what foot leg ankle swell also call swell ankl...
# 45  what cause stroke also call cerebrovascular di...
# 46  what symptoms stroke also call cerebrovascular...
# 47                  how diagnose autoimmune hepatitis
# 48                          what autoimmune hepatitis
# 49   what erectile dysfunction also call ed impotence
# 50                         information csf cell count
# 51  information cell count also call thymus derive...
# 52  information blood count test also call cbc com...
#
#                                           normal_Ques  \
# 0   what reference noonan syndrome polycystic rena...
# 1   what reference noonan syndrome polycystic rena...
# 2   citrobactor freundii ciprofaxin work well bett...
# 3   would like know drug reaction carvedilol mg hy...
# 4   hello would like know take dicyclomine mg phen...
# 5          dementia genetically pass could anyone get
# 6   take loperamide chronic diahrrea stop days bow...
# 7   take loperamide chronic diahrrea stop days bow...
# 8   take amlodipine cause pause rate high wean pro...
# 9   take amlodipine cause pause rate high wean pro...
# 10  need know work place someone shingle especiall...
# 11  question what reason little attentions antipho...
# 12  why recommend medicine take even harm take mor...
# 13  why recommend medicine take even harm take mor...
# 14  electrical high voltage shock cause swallow pr...
# 15  could please tell what bundle blockage what sy...
# 16  infection gum dentist prescribe cephalexin mg ...
# 17  arrhythmia occur ablation what success rate ab...
# 18  low dose naltrexone use treatment severe depre...
# 19                              hantavirus lead death
# 20  want know take gabamentine hydrocodene togethe...
# 21  want know take gabamentine hydrocodene togethe...
# 22  want know take gabamentine hydrocodene togethe...
# 23  want know take gabamentine hydrocodene togethe...
# 24  safe take diclofenac when take lisinopril alev...
# 25  wonder condition trisomy progress time get wor...
# 26  wonder condition trisomy progress time get wor...
# 27  quinine seltzer water ok drink quinine seltzer...
# 28  please inform recommend treatment prevention p...
# 29                     safe take meds wine dinnertime
# 30      look information how prevent shingle outbreak
# 31      father age always leg pain which use medicine
# 32      father age always leg pain which use medicine
# 33      father age always leg pain which use medicine
# 34  recently diagnose cvid person thyroid thyroid ...
# 35  recently diagnose cvid person thyroid thyroid ...
# 36  hi hear order get benefit calcium take magnesi...
# 37  hi hear order get benefit calcium take magnesi...
# 38  hi hear order get benefit calcium take magnesi...
# 39  would like know point direction laboratory sou...
# 40  hello acute chronic cervicitis cause tampon us...
# 41  hello acute chronic cervicitis cause tampon us...
# 42  hello acute chronic cervicitis cause tampon us...
# 43  hello acute chronic cervicitis cause tampon us...
# 44  when suffer fibromyalgia cause swell body swel...
# 45                                             define
# 46                                             define
# 47  what doctor specialize test treatment autoimmu...
# 48  what doctor specialize test treatment autoimmu...
# 49  how long non prescription drug implicate erect...
# 50                   what cause white cells ti uprate
# 51                   what cause white cells ti uprate
# 52                   what cause white cells ti uprate
#
#                                       scientific_Ques
# 0   what relationship noonan syndrome polycystic r...
# 1   what relationship noonan syndrome polycystic r...
# 2   what citrobacter infections what drug use trea...
# 3   show comparable effect beta blocker carvedilol...
# 4   adverse drug interaction report phentermine hy...
# 5   dementia inherit one develop dementia without ...
# 6   take loperamide chronic diahrrea stop periodic...
# 7   take loperamide chronic diahrrea stop periodic...
# 8   how one taper drug amlodipine start atenolol a...
# 9   how one taper drug amlodipine start atenolol a...
# 10  shingle virus contagious workplace especially ...
# 11  what reason little research do help investigat...
# 12           why simvastatin take even rather morning
# 13           why simvastatin take even rather morning
# 14  electrical high voltage shock cause swallow di...
# 15  define branch bundle block symptoms know treat...
# 16  person allergic penicillin likely allergic cep...
# 17  what success rate heart ablation arrhythmia oc...
# 18    low dose naltrexone use treat severe depression
# 19                              what hantavirus fatal
# 20  what efficacy administer gabamentine hydrocodo...
# 21  what efficacy administer gabamentine hydrocodo...
# 22  what efficacy administer gabamentine hydrocodo...
# 23  what efficacy administer gabamentine hydrocodo...
# 24  question concern drug interactions safety take...
# 25    trisomy patau syndrome progressive how diagnose
# 26    trisomy patau syndrome progressive how diagnose
# 27  what extent quinine seltzer water effective tr...
# 28  what recommend treatment prevention protocol m...
# 29              safe take medications wine dinnertime
# 30                     what cause shingle how prevent
# 31         what medication year old male use leg pain
# 32         what medication year old male use leg pain
# 33         what medication year old male use leg pain
# 34  what chance person cvid who also thyroid tumor...
# 35  what chance person cvid who also thyroid tumor...
# 36  calcium supplement beneficial persons who oste...
# 37  calcium supplement beneficial persons who oste...
# 38  calcium supplement beneficial persons who oste...
# 39  where one test ehlers danlos syndrome eds oste...
# 40  chronic cervicitis cause infertility why would...
# 41  chronic cervicitis cause infertility why would...
# 42  chronic cervicitis cause infertility why would...
# 43  chronic cervicitis cause infertility why would...
# 44                      fibromyalgia cause swell body
# 45                     define syncope ischemic stroke
# 46                     define syncope ischemic stroke
# 47  what doctor specialize test treat autoimmune d...
# 48  what doctor specialize test treat autoimmune d...
# 49  how long non aspirin nsaid implicate erectile ...
# 50                   what cause white cells ti uprate
# 51                   what cause white cells ti uprate
# 52                   what cause white cells ti uprate

# %%
rela_incom=rela_incom.reset_index()
rela_incom=rela_incom.drop(columns=['index'])

# %%
for i in range(len(rela_inco['Question_1'])):
    for n in range(len(df_2['Question_1'])):
        if rela_inco['Question_1'][i] == df_2['Question_1'][n] and rela_inco['normal_Ques'][i] == df_2['normal_Ques'][n] :
            df_2['Judge_score'][n]='2.5-IncompRelated'

# %%
df_2['Judge_score'].value_counts()
# Out:
# 1-Incorrect          1282
# 2-Related             564
# 3-Incomplete          162
# 4-Excellent           127
# 2.5-IncompRelated     110
# Name: Judge_score, dtype: Int64

# %%
exc_incom=pd.DataFrame()
exc_incom = df_2.loc[df_2['Judge_score'].str.contains("4-Excellent|3-Incomplete", case=False)]
exc_incom.shape
# Out:
# (289, 4)

# %%
exc_incom.duplicated(subset=['Question_1','normal_Ques']).sum()
# Out:
# 34

# %%
exc_inco=exc_incom[exc_incom.duplicated(subset=['Question_1','normal_Ques'])]

# %%
exc_inco=exc_inco.drop(columns='Judge_score')
exc_inco=exc_inco.reset_index()
exc_inco=exc_inco.drop(columns=['index'])
exc_inco
# Out:
#                                            Question_1  \
# 0       what streptococcal infections also call strep
# 1   what cause macular degeneration age relate als...
# 2   information ear wax also call ear impaction ce...
# 3   what cause diaphragmatic hernia also call hern...
# 4   what outlook diaphragmatic hernia also call he...
# 5   what genetic change relate congenital diaphrag...
# 6                                        what shingle
# 7   what antiphospholipid syndrome also call anti ...
# 8   what genetic change relate antiphospholipid sy...
# 9   antiphospholipid syndrome inherit also call an...
# 10  what treatments antiphospholipid syndrome also...
# 11            what antiphospholipid antibody syndrome
# 12      what cause antiphospholipid antibody syndrome
# 13                     what antiphospholipid syndrome
# 14          what treatments antiphospholipid syndrome
# 15  how diagnose isolate sleep paralysis also call...
# 16  what treatments isolate sleep paralysis also c...
# 17                           what symptoms hantavirus
# 18                                  what appendicitis
# 19  what complications trisomy also call patau syn...
# 20  what trisomy also call bartholin patau syndrom...
# 21  what treatments trisomy also call bartholin pa...
# 22  what complications low blood sugar newborns al...
# 23  what diverticulosis diverticulitis also call d...
# 24  what cause common cold also call upper respira...
# 25    information calcium diet also call diet calcium
# 26  information nicotine tobacco also call withdra...
# 27  what cause foot leg ankle swell also call swel...
# 28  information upper gi small bowel series also c...
# 29                            what cause heart attack
# 30                   how diagnose autoimmune disorder
# 31  need see doctor aortic stenosis also call aort...
# 32  what supravalvular aortic stenosis also call a...
# 33  supravalvular aortic stenosis inherit also cal...
#
#                                           normal_Ques  \
# 0   streptococcus infection cause invasive disease...
# 1   non smoker retire military veteran who subject...
# 2   sometimes drop peroxide ear let bubble couple ...
# 3   congenital diaphragmatic hernia what cause con...
# 4   congenital diaphragmatic hernia what cause con...
# 5   congenital diaphragmatic hernia what cause con...
# 6   need know work place someone shingle especiall...
# 7   question what reason little attentions antipho...
# 8   question what reason little attentions antipho...
# 9   question what reason little attentions antipho...
# 10  question what reason little attentions antipho...
# 11  question what reason little attentions antipho...
# 12  question what reason little attentions antipho...
# 13  question what reason little attentions antipho...
# 14  question what reason little attentions antipho...
# 15                       what exactly sleep paralysis
# 16                       what exactly sleep paralysis
# 17                              hantavirus lead death
# 18  always elevate temperature associate appendicitis
# 19  wonder condition trisomy progress time get wor...
# 20  wonder condition trisomy progress time get wor...
# 21  wonder condition trisomy progress time get wor...
# 22  what reason hypoglycemia newborns what step pr...
# 23  diverticulosis diverticulitis detect cat scan ...
# 24  understand contagion transferrence cold germs ...
# 25  hi hear order get benefit calcium take magnesi...
# 26  kindly explain general effect smoke rather eff...
# 27  when suffer fibromyalgia cause swell body swel...
# 28              lipnodes liver cancer detect upper gi
# 29                   abscess teeth cause heart attack
# 30  what doctor specialize test treatment autoimmu...
# 31                         want know aeortic stenosis
# 32                         want know aeortic stenosis
# 33                         want know aeortic stenosis
#
#                                       scientific_Ques
# 0     streptococcus infection cause diseases wegeners
# 1   could second hand smoke contribute cause get e...
# 2   harmful use peroxide drop ear follow warm wate...
# 3   what cause congenital diaphragmatic hernia lon...
# 4   what cause congenital diaphragmatic hernia lon...
# 5   what cause congenital diaphragmatic hernia lon...
# 6   shingle virus contagious workplace especially ...
# 7   what reason little research do help investigat...
# 8   what reason little research do help investigat...
# 9   what reason little research do help investigat...
# 10  what reason little research do help investigat...
# 11  what reason little research do help investigat...
# 12  what reason little research do help investigat...
# 13  what reason little research do help investigat...
# 14  what reason little research do help investigat...
# 15               what sleep paralysis how affect body
# 16               what sleep paralysis how affect body
# 17                              what hantavirus fatal
# 18  always elevate temperature associate appendicitis
# 19    trisomy patau syndrome progressive how diagnose
# 20    trisomy patau syndrome progressive how diagnose
# 21    trisomy patau syndrome progressive how diagnose
# 22  what cause hypoglycemia newborns way pregnant ...
# 23       ct scan detect diverticulitis diverticulosis
# 24                 what common ways spread cold germs
# 25  calcium supplement beneficial persons who oste...
# 26        what effect smoke nicotine digestive system
# 27                      fibromyalgia cause swell body
# 28    lipnodes liver cancer detect upper gi endoscopy
# 29                 abscessed tooth cause heart attack
# 30  what doctor specialize test treat autoimmune d...
# 31                      what aortic stenosis anything
# 32                      what aortic stenosis anything
# 33                      what aortic stenosis anything

# %%
for i in range(len(exc_inco['Question_1'])):
    for n in range(len(df_2['Question_1'])):
        if exc_inco['Question_1'][i] == df_2['Question_1'][n] and exc_inco['normal_Ques'][i] == df_2['normal_Ques'][n] :
            df_2['Judge_score'][n]='3.5-IncompExcellent'

# %%
# check count of questions in each rank
df_2['Judge_score'].value_counts()
# Out:
# 1-Incorrect            1282
# 2-Related               564
# 3-Incomplete            128
# 2.5-IncompRelated       110
# 4-Excellent              93
# 3.5-IncompExcellent      68
# Name: Judge_score, dtype: Int64

# %%
# check duplicates
df_2.duplicated().sum()
# Out:
# 91

# %%
#check shape of data
df_2.shape
# Out:
# (2245, 4)

# %%
#drop duplicates
df_2= df_2.drop_duplicates()

# %%
#convert ranks to floats
df_2['Judge_score'],_ = df_2['Judge_score'].str.split('-',1).str
df_2['Judge_score']=df_2['Judge_score'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_2.to_csv('file1.csv')

# %%
#split data into train and test
data_train,data_test = train_test_split(df_2, train_size = 0.7, random_state = 2022)

# %%
data_train.shape,data_test.shape
# Out:
# ((1507, 4), (647, 4))

# %%
# reset index of dataset
data_train=data_train.reset_index()
data_train=data_train.drop(columns=['index'])
data_train
# Out:
#                                              Question_1  \
# 0     information age change heart blood vessels als...
# 1                           what forget dose gabapentin
# 2     what infant test procedure preparation also ca...
# 3     what ear discharge also call drainage ear otor...
# 4     what cause cold intolerance also call sensitiv...
# ...                                                 ...
# 1502  what cause leg pain also call pain leg ache le...
# 1503  what cause central sleep apnea also call sleep...
# 1504                       what prescription drug abuse
# 1505         what cause ankle pain also call pain ankle
# 1506                   what treatments morning sickness
#
#                                             normal_Ques  \
# 0     what age get shingle shoot children theur late...
# 1     want know take gabamentine hydrocodene togethe...
# 2     need know work place someone shingle especiall...
# 3     sometimes drop peroxide ear let bubble couple ...
# 4     understand contagion transferrence cold germs ...
# ...                                                 ...
# 1502      father age always leg pain which use medicine
# 1503  sleep apnea surgery hear never find doctor hus...
# 1504  bad uti months take cipro time uti return days...
# 1505                    what cause rib cage pain remedy
# 1506  why recommend medicine take even harm take mor...
#
#                                         scientific_Ques  Judge_score
# 0                  what age one receive shingle vaccine          1.0
# 1     what efficacy administer gabamentine hydrocodo...          2.0
# 2     shingle virus contagious workplace especially ...          1.0
# 3     harmful use peroxide drop ear follow warm wate...          4.0
# 4                    what common ways spread cold germs          1.0
# ...                                                 ...          ...
# 1502         what medication year old male use leg pain          2.0
# 1503       what sleep apnea how effective surgery treat          2.0
# 1504  what besides cipro penicillin drug contain dai...          1.0
# 1505              what cause rib cage pain how remedied          1.0
# 1506           why simvastatin take even rather morning          1.0
#
# [1507 rows x 4 columns]

# %%
# reset index of testset
data_test=data_test.reset_index()
data_test=data_test.drop(columns=['index'])
data_test
# Out:
#                                             Question_1  \
# 0    what cause contact dermatitis also call dermat...
# 1    information personal health record also call e...
# 2    information end life issue also call death die...
# 3               information cholesterol drug treatment
# 4    what treatments hypersensitivity vasculitis al...
# ..                                                 ...
# 642  what symptoms hypersensitivity vasculitis also...
# 643                           what autoimmune diseases
# 644  what cause breathe difficulty also call shortn...
# 645                          information first aid kit
# 646  how prevent uveitis also call iritis par plani...
#
#                                            normal_Ques  \
# 0    dear sir car accident months go person blood s...
# 1    what position homozygout mthfr c health issue ...
# 2    what position homozygout mthfr c health issue ...
# 3    citrobactor freundii ciprofaxin work well bett...
# 4    yes wife dianosed giant cell vasculitis doctor...
# ..                                                 ...
# 642  yes wife dianosed giant cell vasculitis doctor...
# 643                         uveitis autoimmune disease
# 644  want know take gabamentine hydrocodene togethe...
# 645  how much glucose glucagen hypokit curious know...
# 646                         uveitis autoimmune disease
#
#                                        scientific_Ques  Judge_score
# 0    dear sir car accident months go person blood s...          1.0
# 1    what position homozygout mthfr c genetic chang...          1.0
# 2    what position homozygout mthfr c genetic chang...          1.0
# 3    what citrobacter infections what drug use trea...          1.0
# 4    what symptoms associate giant cell vasculitis ...          2.0
# ..                                                 ...          ...
# 642  what symptoms associate giant cell vasculitis ...          1.0
# 643                         uveitis autoimmune disease          2.0
# 644  what efficacy administer gabamentine hydrocodo...          1.0
# 645                     how much glucagon glucagen kit          1.0
# 646                         uveitis autoimmune disease          2.0
#
# [647 rows x 4 columns]

# %% [markdown]
# #### Check if the data is imbalanced or not

# %%
#apply oversampling
#split ranks
label_1=data_train[data_train['Judge_score'] == 1]
label_2=data_train[data_train['Judge_score'] == 2]
label_3=data_train[data_train['Judge_score'] == 3]
label_4=data_train[data_train['Judge_score'] == 4]
label_5=data_train[data_train['Judge_score'] == 2.5]

label_1.shape,label_2.shape,label_3.shape,label_4.shape,label_5.shape
# Out:
# ((897, 4), (385, 4), (89, 4), (70, 4), (39, 4))

# %%
def resample_fun(label_b,Label_a):
    upsample = resample(label_b,
               replace=True,
               n_samples=len(Label_a),
               random_state=42)
    np.unique(np.array(upsample)[:,2],return_counts=True)
    #add sampled ones part to zeros part again
    return upsample

# %%
# resample second rank then concat it with the first rank
samp_1=resample_fun(label_2,label_1)
training_1 = pd.concat([label_1,samp_1])

samp_2=resample_fun(label_3,label_1)
training_2 = pd.concat([training_1,samp_2])

samp_3=resample_fun(label_4,label_1)
training_3 = pd.concat([training_2,samp_3])

samp_4=resample_fun(label_5,label_1)
training_4 = pd.concat([training_3,samp_4])

training_4.shape
# Out:
# (4485, 4)

# %%
data_balanced_train=training_4
data_balanced_train=data_balanced_train.reset_index()
data_balanced_train=data_balanced_train.drop(columns=['index'])
data_balanced_train
# Out:
#                                              Question_1  \
# 0     information age change heart blood vessels als...
# 1     what infant test procedure preparation also ca...
# 2     what cause cold intolerance also call sensitiv...
# 3     what genetic change relate beare stevenson cut...
# 4     information international health also call glo...
# ...                                                 ...
# 4480  what symptoms stroke also call cerebrovascular...
# 4481  what cervicitis also call cervical inflammatio...
# 4482  what leg pain also call pain leg ache leg cram...
# 4483  trisomy inherit also call bartholin patau synd...
# 4484                          what autoimmune hepatitis
#
#                                             normal_Ques  \
# 0     what age get shingle shoot children theur late...
# 1     need know work place someone shingle especiall...
# 2     understand contagion transferrence cold germs ...
# 3     true likely plantar fasiciitis could aggravate...
# 4     what position homozygout mthfr c health issue ...
# ...                                                 ...
# 4480                                             define
# 4481  hello acute chronic cervicitis cause tampon us...
# 4482  quinine seltzer water ok drink quinine seltzer...
# 4483  wonder condition trisomy progress time get wor...
# 4484  what doctor specialize test treatment autoimmu...
#
#                                         scientific_Ques  Judge_score
# 0                  what age one receive shingle vaccine          1.0
# 1     shingle virus contagious workplace especially ...          1.0
# 2                    what common ways spread cold germs          1.0
# 3                     what plantar fasiciitis how treat          1.0
# 4     what position homozygout mthfr c genetic chang...          1.0
# ...                                                 ...          ...
# 4480                     define syncope ischemic stroke          2.5
# 4481  chronic cervicitis cause infertility why would...          2.5
# 4482  what extent quinine seltzer water effective tr...          2.5
# 4483    trisomy patau syndrome progressive how diagnose          2.5
# 4484  what doctor specialize test treat autoimmune d...          2.5
#
# [4485 rows x 4 columns]

# %%
data_balanced_train.to_csv('filetrainbalanced.csv')

# %%
data_test.to_csv('filetestbalanced.csv')

# %% [markdown]
# ## Build Models for the first data(Type Prediction)

# %%
# apply label encoding on qtype
le2 = LabelEncoder()
df_1['Qtype-Fine'] = le2.fit_transform(df_1['Qtype-Fine'].values)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### First Model
# ### SVM

# %%
pipeline = Pipeline([
    ('bow', CountVectorizer()),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', svm.SVC(C=100, degree=2, gamma=1, kernel='linear'))])  # train on TF-IDF vectors
    

# Split the data in Test and Train and make Prediction

_train, _test, label_train, label_test = train_test_split(df_1['Question'], df_1['Qtype-Fine'], test_size=0.3)
pipeline.fit(_train,label_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('classifier', SVC(C=100, degree=2, gamma=1, kernel='linear'))])

# %%
predictions=pipeline.predict(_test)

# %%
cm=confusion_matrix(label_test, predictions) ## confusion matrix
cm
# Out:
# array([[375,   0,   0, ...,   0,   0,   0],
#        [  0,  68,   0, ...,   0,   0,   0],
#        [  0,   0, 636, ...,   0,   0,   0],
#        ...,
#        [  0,   0,   0, ..., 991,   0,   0],
#        [  0,   1,   0, ...,   0, 397,   0],
#        [  0,   0,   0, ...,   0,   0,  32]])

# %%
# Elavuate the Model
print(classification_report(predictions,label_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       375
#            1       1.00      0.93      0.96        73
#            2       1.00      0.99      1.00       642
#            3       1.00      1.00      1.00       311
#            4       0.04      0.04      0.04       137
#            5       1.00      1.00      1.00       490
#            6       1.00      1.00      1.00        10
#            7       1.00      1.00      1.00       329
#            8       1.00      1.00      1.00        31
#            9       1.00      0.97      0.98        33
#           10       1.00      1.00      1.00       344
#           11       1.00      1.00      1.00       532
#           12       1.00      1.00      1.00       310
#           13       1.00      1.00      1.00       307
#           14       1.00      1.00      1.00       312
#           15       1.00      1.00      1.00         7
#           16       1.00      1.00      1.00       123
#           17       1.00      1.00      1.00       397
#           18       0.94      0.94      0.94      2564
#           19       1.00      0.99      1.00       393
#           20       1.00      0.93      0.97        30
#           21       1.00      1.00      1.00        22
#           22       1.00      1.00      1.00        32
#           23       1.00      1.00      1.00         5
#           24       1.00      1.00      1.00       623
#           25       1.00      1.00      1.00       432
#           26       1.00      1.00      1.00       363
#           27       0.99      1.00      1.00       114
#           28       1.00      0.88      0.93         8
#           29       0.99      1.00      1.00       369
#           30       1.00      1.00      1.00        21
#           31       1.00      1.00      1.00       319
#           32       1.00      1.00      1.00        74
#           33       0.98      1.00      0.99       117
#           34       1.00      1.00      1.00      1153
#           35       1.00      1.00      1.00       991
#           36       1.00      1.00      1.00       397
#           37       1.00      1.00      1.00        32
#
#     accuracy                           0.98     12822
#    macro avg       0.97      0.96      0.97     12822
# weighted avg       0.98      0.98      0.98     12822

# %% [markdown]
# #### AUC for SVC

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
y = label_binarize(df_1['Qtype-Fine'], classes=np.arange(0,37))
n_classes = y.shape[1]
# n_classes
x_t, x_te, y_t, y_te = train_test_split(df_1['Question'],y,
    test_size=0.3,stratify = y, random_state = 42)
classifier = OneVsRestClassifier(pipeline)
y_score = classifier.fit(x_t, y_t).decision_function(x_te)
roc_auc = roc_auc_score(y_te, y_score)
print('Area under the curve score =',roc_auc)
# Out:
# Area under the curve score = 0.9978937732299297

# %% [markdown]
# ### Second Model
# ### Logistics Regression

# %%
log_pipeline = Pipeline([
    ('bow', CountVectorizer()),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('log_classifier', LogisticRegression(multi_class='ovr',C=1,solver='liblinear',penalty='l1'))])  # train on TF-IDF vectors

log_pipeline.fit(_train,label_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('log_classifier',
#                  LogisticRegression(C=1, multi_class='ovr', penalty='l1',
#                                     solver='liblinear'))])

# %%
log_predict=log_pipeline.predict(_test)
cm=confusion_matrix(label_test, log_predict) ## confusion matrix
print("Confusion matrix\n\n" ,cm , "\n")
# Out:
# Confusion matrix
#
#  [[375   0   0 ...   0   0   0]
#  [  0  68   0 ...   0   0   0]
#  [  0   0 636 ...   0   0   0]
#  ...
#  [  0   0   0 ... 995   0   0]
#  [  0   0   0 ...   0 398   0]
#  [  0   0   0 ...   0   0  32]]

# %%
print(classification_report(label_test, log_predict)) ## classification report
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       375
#            1       1.00      1.00      1.00        68
#            2       0.99      1.00      1.00       636
#            3       1.00      1.00      1.00       311
#            4       0.43      0.02      0.04       153
#            5       1.00      1.00      1.00       489
#            6       1.00      1.00      1.00        10
#            7       1.00      1.00      1.00       329
#            8       1.00      1.00      1.00        31
#            9       1.00      1.00      1.00        32
#           10       1.00      1.00      1.00       343
#           11       1.00      1.00      1.00       532
#           12       1.00      1.00      1.00       311
#           13       1.00      1.00      1.00       307
#           14       1.00      1.00      1.00       311
#           15       1.00      1.00      1.00         7
#           16       1.00      1.00      1.00       123
#           17       1.00      1.00      1.00       397
#           18       0.94      0.99      0.97      2556
#           19       1.00      1.00      1.00       391
#           20       1.00      1.00      1.00        28
#           21       1.00      1.00      1.00        22
#           22       1.00      1.00      1.00        32
#           23       1.00      1.00      1.00         5
#           24       1.00      1.00      1.00       624
#           25       1.00      1.00      1.00       432
#           26       0.99      0.99      0.99       363
#           27       1.00      0.99      1.00       115
#           28       1.00      1.00      1.00         7
#           29       1.00      1.00      1.00       371
#           30       1.00      1.00      1.00        21
#           31       1.00      1.00      1.00       319
#           32       1.00      1.00      1.00        74
#           33       1.00      0.98      0.99       119
#           34       1.00      1.00      1.00      1153
#           35       1.00      1.00      1.00       995
#           36       1.00      1.00      1.00       398
#           37       1.00      1.00      1.00        32
#
#     accuracy                           0.99     12822
#    macro avg       0.98      0.97      0.97     12822
# weighted avg       0.98      0.99      0.98     12822

# %% [markdown]
# #### AUC for logistic regression

# %%
y = label_binarize(df_1['Qtype-Fine'], classes=np.arange(0,37))
n_classes = y.shape[1]
# n_classes
x_t, x_te, y_t, y_te = train_test_split(df_1['Question'],y,
    test_size=0.3,stratify = y, random_state = 42)
classifier = OneVsRestClassifier(log_pipeline)
y_score = classifier.fit(x_t, y_t).decision_function(x_te)
roc_auc = roc_auc_score(y_te, y_score)
print('Area under the curve score =',roc_auc)
# Out:
# Area under the curve score = 0.9987046551422221

# %% [markdown]
# ## Build model for the secod data(Questions Entailment) and extract similarity features

# %% [markdown]
# ### Define similarity functions

# %% [markdown]
# #### cosine similarity

# %%
def cosine_similarity(vector1, vector2):
    vector1 = np.array(vector1)
    vector2 = np.array(vector2)
    return np.dot(vector1, vector2) / (np.sqrt(np.sum(vector1**2)) * np.sqrt(np.sum(vector2**2)))

# %% [markdown]
# #### jaccard similarity

# %%
from strsimpy.jaccard import Jaccard
def jaccard_similarity(list1, list2):
  jaccard = Jaccard(1)
  return 1- jaccard.distance(list1,list2)

# %% [markdown]
# #### Levenshtein

# %%
def levenshtein_similarity(list1, list2):
  levenshtein = NormalizedLevenshtein()
  return (1 - levenshtein.distance(list1,list2))

# %% [markdown]
# #### Sorensen Dice

# %%
from strsimpy.sorensen_dice import SorensenDice
def sorensen_dice_similarity(list1, list2):
  sorensen_dice = SorensenDice(2)
  return (1- sorensen_dice.distance(list1,list2))

# %% [markdown]
# #### Word overlab

# %%
from strsimpy.overlap_coefficient import OverlapCoefficient
def overlap_coefficient(list1, list2):
  overlap_coefficient = OverlapCoefficient(1)
  return (1- overlap_coefficient.distance(list1,list2))

# %% [markdown]
# #### JaroWinkler

# %%
from strsimpy.jaro_winkler import JaroWinkler
def jaroWinkler_similarity(list1, list2):
  jaroWinkler = JaroWinkler()
  return 1 - jaroWinkler.distance(list1,list2)

# %% [markdown]
# #### Question length ration
# question length ratio (length(PQ)/length(HQ)).

# %%
def question_len_ratio(porposed_question, hypothesis_question):
  return len(porposed_question)/len(hypothesis_question)

# %% [markdown]
# ### Extract similarity features

# %%
def measure_similarity(dftrainq1, dftrainq2,judge_train, dftestq1,dftestq2,judge_test):

    df_tr, df_ts, df_tr_leven, df_te_leven, jar_tra, jar_test, df_tr_jac, df_jac= [], [], [], [], [], [], [], []
    df_qlen, df_soren, df_overlab, dt_qlen, dt_soren, dt_over=[], [], [], [], [], []
   
    #convert to tfidf vectorizer
    vectorizer= TfidfVectorizer()
    df_union=np.concatenate((dftrainq1, dftrainq2), axis=0)
    X = vectorizer.fit(df_union)
    test_vector = X.transform(dftrainq1).toarray()
    x=X.transform(dftrainq2).toarray()
    test_vectort = X.transform(dftestq1).toarray()
    xt=X.transform(dftestq2).toarray()

# apply similarity functions on train data
    for i in range(len(dftrainq1)):  
        result_1=cosine_similarity(x[i], test_vector[i])
        result_2 = levenshtein_similarity(dftrainq1[i], dftrainq2[i])
        jar = jaroWinkler_similarity(dftrainq1[i], dftrainq2[i])
        jac = jaccard_similarity(dftrainq1[i], dftrainq2[i])
        qlen=question_len_ratio(dftrainq1[i], dftrainq2[i])
        soren=sorensen_dice_similarity(dftrainq1[i], dftrainq2[i])
        overlab=overlap_coefficient(dftrainq1[i], dftrainq2[i])

        df_tr.append(result_1)
        df_tr_leven.append(result_2)
        jar_tra.append(jar)
        df_tr_jac.append(jac)
        df_qlen.append(qlen)
        df_soren.append(soren)
        df_overlab.append(overlab)

# apply similarity functions on test data
    for i in range(len(dftestq1)):  
        resultt_1=cosine_similarity(xt[i], test_vectort[i])
        resultt_2=levenshtein_similarity(dftestq1[i], dftestq2[i])
        jart = jaroWinkler_similarity(dftestq1[i], dftestq2[i])
        jact=jaccard_similarity(dftestq1[i], dftestq2[i])
        qlent=question_len_ratio(dftestq1[i], dftestq2[i])
        sorent=sorensen_dice_similarity(dftestq1[i], dftestq2[i])
        overlabt=overlap_coefficient(dftestq1[i], dftestq2[i])

        df_ts.append(resultt_1)
        df_te_leven.append(resultt_2)
        jar_test.append(jart)
        df_jac.append(jact)
        dt_qlen.append(qlent)
        dt_soren.append(sorent)
        dt_over.append(overlabt)

# save similarities into new df
    return pd.DataFrame({'cosine_similarity':df_tr, 'levenshtein_similarity': df_tr_leven,
                         'jaro_winkler': jar_tra,  'jaccard_similarity': df_tr_jac,
                         'Judge_score':judge_train,'question_len_ratio':df_qlen,
                         'sorensen_dice': df_soren,'overlap_coefficient':df_overlab}), pd.DataFrame({'cosine_similarity':df_ts, 'levenshtein_similarity': df_te_leven,
                                                                                                     'jaro_winkler': jar_test,'jaccard_similarity': df_jac,
                                                                                                     'Judge_score':judge_test, 'question_len_ratio':dt_qlen,
                                                                                                     'sorensen_dice':dt_soren, 'overlap_coefficient':dt_over})

# %% [markdown]
# #### Measure similarity for data without oversampling

# %% [markdown]
# #### Measure similarity between data questions and normal questions

# %%
train_sem, test_sem = measure_similarity(data_train['Question_1'],data_train['normal_Ques'],data_train['Judge_score'],
                                         data_test['Question_1'],data_test['normal_Ques'],data_test['Judge_score'])

# %%
train_sem
# Out:
#       cosine_similarity  levenshtein_similarity  jaro_winkler  \
# 0              0.152810                0.244444      0.695702
# 1              0.017863                0.220930      0.592208
# 2              0.000000                0.232143      0.611295
# 3              0.198752                0.265823      0.640105
# 4              0.226780                0.197183      0.652837
# ...                 ...                     ...           ...
# 1502           0.380163                0.333333      0.688647
# 1503           0.155580                0.192513      0.599557
# 1504           0.155488                0.122066      0.555723
# 1505           0.217084                0.476190      0.690721
# 1506           0.210174                0.240000      0.581322
#
#       jaccard_similarity  Judge_score  question_len_ratio  sorensen_dice  \
# 0               0.625000          1.0            1.022727       0.393162
# 1               0.681818          2.0            0.313953       0.417582
# 2               0.714286          1.0            1.898305       0.258065
# 3               0.714286          4.0            0.886076       0.307692
# 4               0.761905          1.0            1.014286       0.391753
# ...                  ...          ...                 ...            ...
# 1502            0.800000          2.0            1.266667       0.486486
# 1503            0.608696          2.0            0.320856       0.308824
# 1504            0.739130          1.0            0.131455       0.331034
# 1505            0.571429          1.0            1.354839       0.576923
# 1506            0.777778          1.0            0.640000       0.434783
#
#       overlap_coefficient
# 0                0.833333
# 1                0.937500
# 2                0.882353
# 3                0.937500
# 4                0.941176
# ...                   ...
# 1502             0.941176
# 1503             1.000000
# 1504             1.000000
# 1505             0.800000
# 1506             0.933333
#
# [1507 rows x 8 columns]

# %% [markdown]
# #### Measure similarity between data questions and scientific questions

# %%
train_scien_sem, test_scien_sem = measure_similarity(data_train['Question_1'],data_train['scientific_Ques'],data_train['Judge_score'],
                                                     data_test['Question_1'],data_test['scientific_Ques'],data_test['Judge_score'])

# %%
train_scien_sem
# Out:
#       cosine_similarity  levenshtein_similarity  jaro_winkler  \
# 0              0.299469                0.255556      0.629798
# 1              0.018082                0.285714      0.667690
# 2              0.058486                0.276786      0.625906
# 3              0.397202                0.285714      0.673518
# 4              0.311653                0.295775      0.620251
# ...                 ...                     ...           ...
# 1502           0.409653                0.385965      0.664750
# 1503           0.483072                0.366667      0.662151
# 1504           0.097584                0.268293      0.649535
# 1505           0.237268                0.404762      0.676971
# 1506           0.247483                0.225000      0.741012
#
#       jaccard_similarity  Judge_score  question_len_ratio  sorensen_dice  \
# 0               0.736842          1.0            2.500000       0.295455
# 1               0.789474          2.0            0.385714       0.390244
# 2               0.809524          1.0            1.750000       0.350515
# 3               0.666667          4.0            1.044776       0.279570
# 4               0.700000          1.0            2.088235       0.309859
# ...                  ...          ...                 ...            ...
# 1502            0.894737          2.0            1.357143       0.507042
# 1503            0.736842          2.0            1.363636       0.493151
# 1504            0.894737          1.0            0.341463       0.444444
# 1505            0.650000          1.0            1.135135       0.526316
# 1506            0.823529          1.0            0.800000       0.400000
#
#       overlap_coefficient
# 0                0.933333
# 1                0.937500
# 2                1.000000
# 3                0.875000
# 4                0.823529
# ...                   ...
# 1502             1.000000
# 1503             1.000000
# 1504             1.000000
# 1505             0.866667
# 1506             0.933333
#
# [1507 rows x 8 columns]

# %% [markdown]
# #### Measure similarity for oversampled data

# %% [markdown]
# #### Measure similarity between data questions and normal questions

# %%
train_oversam_sem, test_oversam_sem = measure_similarity(data_balanced_train['Question_1'],data_balanced_train['normal_Ques'],
                                                         data_balanced_train['Judge_score'],data_test['Question_1'],data_test['normal_Ques'],
                                                         data_test['Judge_score'])

# %%
train_oversam_sem
# Out:
#       cosine_similarity  levenshtein_similarity  jaro_winkler  \
# 0              0.144237                0.244444      0.695702
# 1              0.000000                0.232143      0.611295
# 2              0.209292                0.197183      0.652837
# 3              0.000000                0.273333      0.686377
# 4              0.238912                0.261538      0.614045
# ...                 ...                     ...           ...
# 4480           0.000000                0.030612      0.621315
# 4481           0.426458                0.205036      0.580808
# 4482           0.322955                0.253968      0.573097
# 4483           0.142308                0.268293      0.704059
# 4484           0.304135                0.285714      0.651558
#
#       jaccard_similarity  Judge_score  question_len_ratio  sorensen_dice  \
# 0               0.625000          1.0            1.022727       0.393162
# 1               0.714286          1.0            1.898305       0.258065
# 2               0.761905          1.0            1.014286       0.391753
# 3               0.869565          1.0            1.339286       0.343284
# 4               0.714286          1.0            0.861538       0.387097
# ...                  ...          ...                 ...            ...
# 4480            0.217391          2.5           32.666667       0.043478
# 4481            0.708333          2.5            0.241007       0.397516
# 4482            0.727273          2.5            0.404762       0.326531
# 4483            0.809524          2.5            1.308511       0.482759
# 4484            0.722222          2.5            0.446429       0.434783
#
#       overlap_coefficient
# 0                0.833333
# 1                0.882353
# 2                0.941176
# 3                1.000000
# 4                0.937500
# ...                   ...
# 4480             1.000000
# 4481             1.000000
# 4482             1.000000
# 4483             0.944444
# 4484             1.000000
#
# [4485 rows x 8 columns]

# %% [markdown]
# #### Measure similarity between data questions and scientific questions

# %%
train_sam_scien_sem, test_sam_scien_sem = measure_similarity(data_balanced_train['Question_1'],data_balanced_train['scientific_Ques'],
                                                             data_balanced_train['Judge_score'],data_test['Question_1'],data_test['scientific_Ques'],
                                                             data_test['Judge_score'])

# %%
train_sam_scien_sem
# Out:
#       cosine_similarity  levenshtein_similarity  jaro_winkler  \
# 0              0.310780                0.255556      0.629798
# 1              0.054342                0.276786      0.625906
# 2              0.285262                0.295775      0.620251
# 3              0.004332                0.166667      0.564270
# 4              0.000000                0.205479      0.612410
# ...                 ...                     ...           ...
# 4480           0.466893                0.137755      0.562132
# 4481           0.355819                0.375000      0.722390
# 4482           0.339385                0.355932      0.634450
# 4483           0.650544                0.300813      0.630798
# 4484           0.298944                0.301887      0.625786
#
#       jaccard_similarity  Judge_score  question_len_ratio  sorensen_dice  \
# 0               0.736842          1.0            2.500000       0.295455
# 1               0.809524          1.0            1.750000       0.350515
# 2               0.700000          1.0            2.088235       0.309859
# 3               0.590909          1.0            4.545455       0.318182
# 4               0.714286          1.0            0.767123       0.291667
# ...                  ...          ...                 ...            ...
# 4480            0.695652          2.5            6.533333       0.333333
# 4481            0.761905          2.5            0.930556       0.581395
# 4482            0.681818          2.5            0.864407       0.379747
# 4483            0.714286          2.5            2.617021       0.468085
# 4484            0.722222          2.5            0.471698       0.500000
#
#       overlap_coefficient
# 0                0.933333
# 1                1.000000
# 2                0.823529
# 3                0.866667
# 4                0.937500
# ...                   ...
# 4480             1.000000
# 4481             0.941176
# 4482             0.937500
# 4483             0.833333
# 4484             1.000000
#
# [4485 rows x 8 columns]

# %% [markdown]
# ### Build Model

# %%
def model_(train, test, model):
    xx=train.drop(columns=['Judge_score'])
    yy=train['Judge_score']
    xtes=test.drop(columns=['Judge_score'])
    ytes=test['Judge_score']
    polyreg=model
    polyreg.fit(xx,yy)
    prediction= polyreg.predict(xtes)
    print('Mean Absolute Error : ', metrics.mean_absolute_error(ytes, prediction))
    print('Mean Square Error : ', mean_squared_error(ytes, prediction))

    return pd.DataFrame({'Actual':ytes,'Predicted':prediction})

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### Evaluation for Decision Tree Regressor

# %% [markdown]
# ##### For balanced data (normal ques)

# %%
norm_bal_sim=model_(train_oversam_sem, test_oversam_sem, tree.DecisionTreeRegressor())
# Out:
# Mean Absolute Error :  0.6351800740904295
# Mean Square Error :  1.0443430473826716

# %%
norm_bal_sim
# Out:
#      Actual  Predicted
# 0       1.0   1.000000
# 1       1.0   1.000000
# 2       1.0   1.000000
# 3       1.0   2.000000
# 4       2.0   1.000000
# ..      ...        ...
# 642     1.0   1.000000
# 643     2.0   1.666667
# 644     1.0   1.000000
# 645     1.0   2.500000
# 646     2.0   4.000000
#
# [647 rows x 2 columns]

# %% [markdown]
# ##### For balanced data(scientific ques)

# %%
scin_bal_sim=model_(train_sam_scien_sem, test_sam_scien_sem, tree.DecisionTreeRegressor())
# Out:
# Mean Absolute Error :  0.5594100129648816
# Mean Square Error :  0.8590936566957338

# %%
scin_bal_sim
# Out:
#      Actual  Predicted
# 0       1.0        1.0
# 1       1.0        1.0
# 2       1.0        1.0
# 3       1.0        3.0
# 4       2.0        2.0
# ..      ...        ...
# 642     1.0        4.0
# 643     2.0        4.0
# 644     1.0        1.0
# 645     1.0        1.0
# 646     2.0        1.0
#
# [647 rows x 2 columns]

# %% [markdown]
# ##### For normal questions similarity

# %%
normal_sim=model_(train_sem, test_sem, tree.DecisionTreeRegressor())
# Out:
# Mean Absolute Error :  0.6058732612055642
# Mean Square Error :  0.9945904173106646

# %%
normal_sim
# Out:
#      Actual  Predicted
# 0       1.0        1.0
# 1       1.0        2.0
# 2       1.0        1.0
# 3       1.0        2.0
# 4       2.0        1.0
# ..      ...        ...
# 642     1.0        2.0
# 643     2.0        1.0
# 644     1.0        1.0
# 645     1.0        1.0
# 646     2.0        4.0
#
# [647 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
plt.hist(normal_sim['Predicted'])
plt.show()

# %% [markdown]
# ##### For scientific questions similarity

# %%
scin_sim=model_(train_scien_sem, test_scien_sem, tree.DecisionTreeRegressor())
# Out:
# Mean Absolute Error :  0.5695517774343122
# Mean Square Error :  0.8937403400309119

# %%
scin_sim
# Out:
#      Actual  Predicted
# 0       1.0        1.0
# 1       1.0        1.0
# 2       1.0        1.0
# 3       1.0        3.0
# 4       2.0        3.0
# ..      ...        ...
# 642     1.0        4.0
# 643     2.0        4.0
# 644     1.0        1.0
# 645     1.0        1.0
# 646     2.0        2.0
#
# [647 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
plt.hist(scin_sim['Predicted'])
plt.show()

# %%
plt.hist(normal_sim['Actual'])
plt.show()

# %% [markdown]
# #### Evaluation for polynomial regression

# %% [markdown]
# ##### For balanced data (normal ques)

# %%
norm_bal_sim=model_(train_oversam_sem, test_oversam_sem, make_pipeline(PolynomialFeatures(2),LinearRegression()))
# Out:
# Mean Absolute Error :  1.0162483536739342
# Mean Square Error :  1.315332150306355

# %%
norm_bal_sim
# Out:
#      Actual  Predicted
# 0       1.0   1.825719
# 1       1.0   2.520169
# 2       1.0   2.362648
# 3       1.0   2.086367
# 4       2.0   2.217128
# ..      ...        ...
# 642     1.0   2.189738
# 643     2.0   2.689535
# 644     1.0   2.153367
# 645     1.0   2.859784
# 646     2.0   2.419424
#
# [647 rows x 2 columns]

# %% [markdown]
# ##### For balanced data(scientific ques)

# %%
scin_bal_sim=model_(train_sam_scien_sem, test_sam_scien_sem, make_pipeline(PolynomialFeatures(2),LinearRegression()))
# Out:
# Mean Absolute Error :  0.8419182765484519
# Mean Square Error :  1.0040746650977777

# %%
scin_bal_sim
# Out:
#      Actual  Predicted
# 0       1.0   1.539687
# 1       1.0   1.484804
# 2       1.0   1.983969
# 3       1.0   3.050203
# 4       2.0   2.973025
# ..      ...        ...
# 642     1.0   2.727810
# 643     2.0   4.205449
# 644     1.0   1.540047
# 645     1.0   1.183677
# 646     2.0   3.156712
#
# [647 rows x 2 columns]

# %% [markdown]
# ##### For normal questions similarity

# %%
normal_sim=model_(train_sem, test_sem, make_pipeline(PolynomialFeatures(2),LinearRegression()))
# Out:
# Mean Absolute Error :  0.6125595352196436
# Mean Square Error :  0.6128784700173027

# %%
normal_sim
# Out:
#      Actual  Predicted
# 0       1.0   1.158524
# 1       1.0   1.603043
# 2       1.0   1.523941
# 3       1.0   1.235275
# 4       2.0   1.523041
# ..      ...        ...
# 642     1.0   1.494064
# 643     2.0   2.384476
# 644     1.0   0.975693
# 645     1.0   1.811920
# 646     2.0   2.069336
#
# [647 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
plt.hist(normal_sim['Predicted'])
plt.show()

# %% [markdown]
# ##### For scientific questions similarity

# %%
scin_sim=model_(train_scien_sem, test_scien_sem, make_pipeline(PolynomialFeatures(2),LinearRegression()))
# Out:
# Mean Absolute Error :  0.5270517916909213
# Mean Square Error :  0.49803736202244436

# %%
scin_sim
# Out:
#      Actual  Predicted
# 0       1.0   0.968878
# 1       1.0   1.037755
# 2       1.0   1.373070
# 3       1.0   2.382917
# 4       2.0   2.163127
# ..      ...        ...
# 642     1.0   2.162326
# 643     2.0   3.703432
# 644     1.0   1.130467
# 645     1.0   1.144130
# 646     2.0   2.369515
#
# [647 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
plt.hist(scin_sim['Predicted'])
plt.show()

# %%
plt.hist(normal_sim['Actual'])
plt.show()

# %%
# for i in range(len(scin_sim['Predicted'])):
#     if scin_sim['Predicted'][i] >= 3.50001 : 
#        scin_sim['Predicted'][i]= 4
#     if scin_sim['Predicted'][i] <= 3.5 and scin_sim['Predicted'][i] >= 2.50001:
#        scin_sim['Predicted'][i]= 3
#     if scin_sim['Predicted'][i] < 3 and scin_sim['Predicted'][i] > 2.3:
#        scin_sim['Predicted'][i]= 2.5
#     if scin_sim['Predicted'][i] <= 2.3 and scin_sim['Predicted'][i] >= 1.600001:
#        scin_sim['Predicted'][i]= 2
#     if scin_sim['Predicted'][i] < 1.60001:
#        scin_sim['Predicted'][i]= 1

# %%
# print('Mean Absolute Error : ', metrics.mean_absolute_error(scin_sim['Actual'], scin_sim['Predicted']))

# %% [markdown]
# ## Try Deep Learning Model for check text similarity

# %%
X_train=data_train.drop(columns=['scientific_Ques','Judge_score'])
y_train=data_train['Judge_score']
X_val=data_test.drop(columns=['scientific_Ques','Judge_score'])
y_val=data_test['Judge_score']

# %%
X_train
# Out:
#                                              Question_1  \
# 0     information age change heart blood vessels als...
# 1                           what forget dose gabapentin
# 2     what infant test procedure preparation also ca...
# 3     what ear discharge also call drainage ear otor...
# 4     what cause cold intolerance also call sensitiv...
# ...                                                 ...
# 1502  what cause leg pain also call pain leg ache le...
# 1503  what cause central sleep apnea also call sleep...
# 1504                       what prescription drug abuse
# 1505         what cause ankle pain also call pain ankle
# 1506                   what treatments morning sickness
#
#                                             normal_Ques
# 0     what age get shingle shoot children theur late...
# 1     want know take gabamentine hydrocodene togethe...
# 2     need know work place someone shingle especiall...
# 3     sometimes drop peroxide ear let bubble couple ...
# 4     understand contagion transferrence cold germs ...
# ...                                                 ...
# 1502      father age always leg pain which use medicine
# 1503  sleep apnea surgery hear never find doctor hus...
# 1504  bad uti months take cipro time uti return days...
# 1505                    what cause rib cage pain remedy
# 1506  why recommend medicine take even harm take mor...
#
# [1507 rows x 2 columns]

# %%
X_train['text'] = X_train[['Question_1','normal_Ques']].apply(lambda x:str(x[0])+" "+str(x[1]), axis=1)

# %%
X_train['text'][0]
# Out:
# 'information age change heart blood vessels also call heart disease age atherosclerosis age what age get shingle shoot children theur late early three bad case chicken pox children'

# %%
t = Tokenizer()
t.fit_on_texts(X_train['text'].values)

# %%
X_train['clean_q1'] = X_train['Question_1'].astype(str)
X_train['clean_q2'] = X_train['normal_Ques'].astype(str)
X_val['clean_q1'] = X_val['Question_1'].astype(str)
X_val['clean_q2'] = X_val['normal_Ques'].astype(str)

# %%
train_q1_seq = t.texts_to_sequences(X_train['clean_q1'].values)
train_q2_seq = t.texts_to_sequences(X_train['clean_q2'].values)
val_q1_seq = t.texts_to_sequences(X_val['clean_q1'].values)
val_q2_seq = t.texts_to_sequences(X_val['clean_q2'].values)

# %%
train_q1_seq[0]
# Out:
# [6, 61, 287, 74, 27, 1758, 2, 3, 74, 14, 61, 1759, 61]

# %%
len_vec = [len(sent_vec) for sent_vec in train_q1_seq]

# %%
np.max(len_vec)
# Out:
# 67

# %%
sns.distplot(len_vec)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
len_vec = [len(sent_vec) for sent_vec in train_q2_seq]

# %%
np.max(len_vec)
# Out:
# 81

# %%
sns.distplot(len_vec)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
max_len = 40

# %%
train_q1_seq = pad_sequences(train_q1_seq, maxlen=max_len, padding='post')
train_q2_seq = pad_sequences(train_q2_seq, maxlen=max_len, padding='post')
val_q1_seq = pad_sequences(val_q1_seq, maxlen=max_len, padding='post')
val_q2_seq = pad_sequences(val_q2_seq, maxlen=max_len, padding='post')

# %%
embeddings_index = {}
f = open('/content/drive/MyDrive/glove.6B.300d[1].txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:])
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400001 word vectors.

# %%
not_present_list = []
vocab_size = len(t.word_index) + 1
print('Loaded %s word vectors.' % len(embeddings_index))
embedding_matrix = np.zeros((vocab_size, len(embeddings_index['no'])))
for word, i in t.word_index.items():
    if word in embeddings_index.keys():
        embedding_vector = embeddings_index.get(word)
    else:
        not_present_list.append(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
    else:
        embedding_matrix[i] = np.zeros(300)
# Out:
# Loaded 400001 word vectors.

# %%
def cosine_distance(vests):
    x, y = vests
    x = K.l2_normalize(x, axis=-1)
    y = K.l2_normalize(y, axis=-1)
    return -K.mean(x * y, axis=-1, keepdims=True)

def cos_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0],1)

# %%
input_1 = Input(shape=(train_q1_seq.shape[1],))
input_2 = Input(shape=(train_q2_seq.shape[1],))


common_embed = Embedding(name="synopsis_embedd",input_dim =len(t.word_index)+1, 
                       output_dim=len(embeddings_index['no']),weights=[embedding_matrix], 
                       input_length=train_q1_seq.shape[1],trainable=False) 
lstm_1 = common_embed(input_1)
lstm_2 = common_embed(input_2)


common_lstm = LSTM(64,return_sequences=True, activation="relu")
vector_1 = common_lstm(lstm_1)
vector_1 = Flatten()(vector_1)

vector_2 = common_lstm(lstm_2)
vector_2 = Flatten()(vector_2)

x3 = Subtract()([vector_1, vector_2])
x3 = Multiply()([x3, x3])

x1_ = Multiply()([vector_1, vector_1])
x2_ = Multiply()([vector_2, vector_2])
x4 = Subtract()([x1_, x2_])
    
    #https://stackoverflow.com/a/51003359/10650182
x5 = Lambda(cosine_distance, output_shape=cos_dist_output_shape)([vector_1, vector_2])
conc = Concatenate(axis=-1)([x5,x4, x3])

x = Dense(256, activation="relu", name='conc_layer')(conc)
x = Dropout(0.01)(x)
out = Dense(1, activation='linear',name = 'out')(x)

model = Model([input_1, input_2], out)

model.compile(loss="mean_squared_error",  optimizer=Adam(0.00001))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 40)]         0           []
#
#  input_2 (InputLayer)           [(None, 40)]         0           []
#
#  synopsis_embedd (Embedding)    (None, 40, 300)      677700      ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lstm (LSTM)                    (None, 40, 64)       93440       ['synopsis_embedd[0][0]',
#                                                                   'synopsis_embedd[1][0]']
#
#  flatten (Flatten)              (None, 2560)         0           ['lstm[0][0]']
#
#  flatten_1 (Flatten)            (None, 2560)         0           ['lstm[1][0]']
#
#  multiply_1 (Multiply)          (None, 2560)         0           ['flatten[0][0]',
#                                                                   'flatten[0][0]']
#
#  multiply_2 (Multiply)          (None, 2560)         0           ['flatten_1[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  subtract (Subtract)            (None, 2560)         0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  subtract_1 (Subtract)          (None, 2560)         0           ['multiply_1[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  multiply (Multiply)            (None, 2560)         0           ['subtract[0][0]',
#                                                                   'subtract[0][0]']
#
#  concatenate (Concatenate)      (None, 5121)         0           ['lambda[0][0]',
#                                                                   'subtract_1[0][0]',
#                                                                   'multiply[0][0]']
#
#  conc_layer (Dense)             (None, 256)          1311232     ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 256)          0           ['conc_layer[0][0]']
#
#  out (Dense)                    (None, 1)            257         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2,082,629
# Trainable params: 1,404,929
# Non-trainable params: 677,700
# __________________________________________________________________________________________________

# %%
model.fit([train_q1_seq,train_q2_seq],y_train.values.reshape(-1,1), epochs = 150,
          batch_size=64,validation_data=([val_q1_seq, val_q2_seq],y_val.values.reshape(-1,1)))
# Out:
# Epoch 1/150
# 24/24 [==============================] - 8s 175ms/step - loss: 3.1768 - val_loss: 2.8514
# Epoch 2/150
# 24/24 [==============================] - 3s 144ms/step - loss: 2.9229 - val_loss: 2.5989
# Epoch 3/150
# 24/24 [==============================] - 3s 141ms/step - loss: 2.6794 - val_loss: 2.3524
# Epoch 4/150
# 24/24 [==============================] - 3s 139ms/step - loss: 2.4433 - val_loss: 2.1101
# Epoch 5/150
# 24/24 [==============================] - 4s 163ms/step - loss: 2.2213 - val_loss: 1.8885
# Epoch 6/150
# 24/24 [==============================] - 3s 145ms/step - loss: 2.0254 - val_loss: 1.7014
# Epoch 7/150
# 24/24 [==============================] - 3s 139ms/step - loss: 1.8673 - val_loss: 1.5385
# Epoch 8/150
# 24/24 [==============================] - 3s 139ms/step - loss: 1.7292 - val_loss: 1.4024
# Epoch 9/150
# 24/24 [==============================] - 3s 144ms/step - loss: 1.6084 - val_loss: 1.2869
# Epoch 10/150
# 24/24 [==============================] - 3s 145ms/step - loss: 1.5035 - val_loss: 1.1916
# Epoch 11/150
# 24/24 [==============================] - 3s 142ms/step - loss: 1.4105 - val_loss: 1.1098
# Epoch 12/150
# 24/24 [==============================] - 3s 139ms/step - loss: 1.3273 - val_loss: 1.0420
# Epoch 13/150
# 24/24 [==============================] - 4s 146ms/step - loss: 1.2568 - val_loss: 0.9863
# Epoch 14/150
# 24/24 [==============================] - 4s 153ms/step - loss: 1.1909 - val_loss: 0.9458
# Epoch 15/150
# 24/24 [==============================] - 3s 141ms/step - loss: 1.1374 - val_loss: 0.9095
# Epoch 16/150
# 24/24 [==============================] - 3s 137ms/step - loss: 1.0889 - val_loss: 0.8788
# Epoch 17/150
# 24/24 [==============================] - 3s 141ms/step - loss: 1.0485 - val_loss: 0.8557
# Epoch 18/150
# 24/24 [==============================] - 3s 144ms/step - loss: 1.0132 - val_loss: 0.8347
# Epoch 19/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.9776 - val_loss: 0.8167
# Epoch 20/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.9506 - val_loss: 0.8007
# Epoch 21/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.9239 - val_loss: 0.7847
# Epoch 22/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.9001 - val_loss: 0.7719
# Epoch 23/150
# 24/24 [==============================] - 3s 141ms/step - loss: 0.8752 - val_loss: 0.7595
# Epoch 24/150
# 24/24 [==============================] - 3s 140ms/step - loss: 0.8551 - val_loss: 0.7468
# Epoch 25/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.8357 - val_loss: 0.7362
# Epoch 26/150
# 24/24 [==============================] - 4s 159ms/step - loss: 0.8145 - val_loss: 0.7262
# Epoch 27/150
# 24/24 [==============================] - 4s 148ms/step - loss: 0.7977 - val_loss: 0.7150
# Epoch 28/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.7783 - val_loss: 0.7049
# Epoch 29/150
# 24/24 [==============================] - 3s 140ms/step - loss: 0.7619 - val_loss: 0.6936
# Epoch 30/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.7445 - val_loss: 0.6853
# Epoch 31/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.7288 - val_loss: 0.6763
# Epoch 32/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.7126 - val_loss: 0.6678
# Epoch 33/150
# 24/24 [==============================] - 3s 138ms/step - loss: 0.6958 - val_loss: 0.6593
# Epoch 34/150
# 24/24 [==============================] - 3s 140ms/step - loss: 0.6833 - val_loss: 0.6513
# Epoch 35/150
# 24/24 [==============================] - 5s 219ms/step - loss: 0.6674 - val_loss: 0.6424
# Epoch 36/150
# 24/24 [==============================] - 4s 144ms/step - loss: 0.6527 - val_loss: 0.6350
# Epoch 37/150
# 24/24 [==============================] - 4s 150ms/step - loss: 0.6413 - val_loss: 0.6272
# Epoch 38/150
# 24/24 [==============================] - 3s 145ms/step - loss: 0.6270 - val_loss: 0.6199
# Epoch 39/150
# 24/24 [==============================] - 4s 150ms/step - loss: 0.6124 - val_loss: 0.6119
# Epoch 40/150
# 24/24 [==============================] - 3s 146ms/step - loss: 0.6006 - val_loss: 0.6042
# Epoch 41/150
# 24/24 [==============================] - 3s 143ms/step - loss: 0.5901 - val_loss: 0.5984
# Epoch 42/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.5775 - val_loss: 0.5917
# Epoch 43/150
# 24/24 [==============================] - 4s 164ms/step - loss: 0.5634 - val_loss: 0.5854
# Epoch 44/150
# 24/24 [==============================] - 7s 271ms/step - loss: 0.5532 - val_loss: 0.5801
# Epoch 45/150
# 24/24 [==============================] - 4s 150ms/step - loss: 0.5414 - val_loss: 0.5732
# Epoch 46/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.5316 - val_loss: 0.5680
# Epoch 47/150
# 24/24 [==============================] - 4s 147ms/step - loss: 0.5193 - val_loss: 0.5596
# Epoch 48/150
# 24/24 [==============================] - 3s 138ms/step - loss: 0.5093 - val_loss: 0.5561
# Epoch 49/150
# 24/24 [==============================] - 4s 151ms/step - loss: 0.4978 - val_loss: 0.5506
# Epoch 50/150
# 24/24 [==============================] - 3s 140ms/step - loss: 0.4904 - val_loss: 0.5444
# Epoch 51/150
# 24/24 [==============================] - 3s 138ms/step - loss: 0.4803 - val_loss: 0.5391
# Epoch 52/150
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4712 - val_loss: 0.5332
# Epoch 53/150
# 24/24 [==============================] - 3s 138ms/step - loss: 0.4639 - val_loss: 0.5294
# Epoch 54/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.4543 - val_loss: 0.5238
# Epoch 55/150
# 24/24 [==============================] - 3s 140ms/step - loss: 0.4472 - val_loss: 0.5207
# Epoch 56/150
# 24/24 [==============================] - 3s 142ms/step - loss: 0.4383 - val_loss: 0.5155
# Epoch 57/150
# 24/24 [==============================] - 3s 142ms/step - loss: 0.4319 - val_loss: 0.5117
# Epoch 58/150
# 24/24 [==============================] - 3s 142ms/step - loss: 0.4232 - val_loss: 0.5071
# Epoch 59/150
# 24/24 [==============================] - 3s 139ms/step - loss: 0.4172 - val_loss: 0.5034
# Epoch 60/150
# 24/24 [==============================] - 3s 138ms/step - loss: 0.4107 - val_loss: 0.4971
# Epoch 61/150
# 24/24 [==============================] - 3s 142ms/step - loss: 0.4053 - val_loss: 0.4948
# Epoch 62/150
# 24/24 [==============================] - 3s 145ms/step - loss: 0.3977 - val_loss: 0.4936
# Epoch 63/150
# 24/24 [==============================] - 4s 150ms/step - loss: 0.3921 - val_loss: 0.4877
# Epoch 64/150
# 24/24 [==============================] - 3s 141ms/step - loss: 0.3855 - val_loss: 0.4832
# Epoch 65/150
# 24/24 [==============================] - 3s 147ms/step - loss: 0.3802 - val_loss: 0.4819
# Epoch 66/150
# 24/24 [==============================] - 4s 183ms/step - loss: 0.3739 - val_loss: 0.4780
# Epoch 67/150
# 24/24 [==============================] - 4s 146ms/step - loss: 0.3687 - val_loss: 0.4758
# Epoch 68/150
# 24/24 [==============================] - 4s 145ms/step - loss: 0.3637 - val_loss: 0.4729
# Epoch 69/150
# 24/24 [==============================] - 4s 160ms/step - loss: 0.3602 - val_loss: 0.4694
# Epoch 70/150
# 24/24 [==============================] - 4s 160ms/step - loss: 0.3545 - val_loss: 0.4677
# Epoch 71/150
# 24/24 [==============================] - 4s 148ms/step - loss: 0.3507 - val_loss: 0.4659
# Epoch 72/150
# 24/24 [==============================] - 4s 159ms/step - loss: 0.3440 - val_loss: 0.4629
# Epoch 73/150
# 24/24 [==============================] - 4s 158ms/step - loss: 0.3408 - val_loss: 0.4603
# Epoch 74/150
# 24/24 [==============================] - 3s 145ms/step - loss: 0.3393 - val_loss: 0.4599
# Epoch 75/150
# 24/24 [==============================] - 4s 163ms/step - loss: 0.3331 - val_loss: 0.4567
# Epoch 76/150
# 24/24 [==============================] - 4s 149ms/step - loss: 0.3288 - val_loss: 0.4543
# Epoch 77/150
# 24/24 [==============================] - 4s 155ms/step - loss: 0.3242 - val_loss: 0.4519
# Epoch 78/150
# 24/24 [==============================] - 4s 166ms/step - loss: 0.3217 - val_loss: 0.4513
# Epoch 79/150
# 24/24 [==============================] - 4s 160ms/step - loss: 0.3179 - val_loss: 0.4494
# Epoch 80/150
# 24/24 [==============================] - 4s 174ms/step - loss: 0.3136 - val_loss: 0.4468
# Epoch 81/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.3094 - val_loss: 0.4466
# Epoch 82/150
# 24/24 [==============================] - 4s 158ms/step - loss: 0.3071 - val_loss: 0.4475
# Epoch 83/150
# 24/24 [==============================] - 4s 164ms/step - loss: 0.3051 - val_loss: 0.4455
# Epoch 84/150
# 24/24 [==============================] - 4s 170ms/step - loss: 0.3017 - val_loss: 0.4413
# Epoch 85/150
# 24/24 [==============================] - 4s 148ms/step - loss: 0.2980 - val_loss: 0.4407
# Epoch 86/150
# 24/24 [==============================] - 4s 145ms/step - loss: 0.2954 - val_loss: 0.4406
# Epoch 87/150
# 24/24 [==============================] - 3s 143ms/step - loss: 0.2928 - val_loss: 0.4406
# Epoch 88/150
# 24/24 [==============================] - 4s 161ms/step - loss: 0.2902 - val_loss: 0.4406
# Epoch 89/150
# 24/24 [==============================] - 4s 167ms/step - loss: 0.2850 - val_loss: 0.4381
# Epoch 90/150
# 24/24 [==============================] - 6s 262ms/step - loss: 0.2827 - val_loss: 0.4374
# Epoch 91/150
# 24/24 [==============================] - 4s 161ms/step - loss: 0.2804 - val_loss: 0.4378
# Epoch 92/150
# 24/24 [==============================] - 4s 154ms/step - loss: 0.2773 - val_loss: 0.4329
# Epoch 93/150
# 24/24 [==============================] - 4s 150ms/step - loss: 0.2754 - val_loss: 0.4339
# Epoch 94/150
# 24/24 [==============================] - 4s 154ms/step - loss: 0.2720 - val_loss: 0.4350
# Epoch 95/150
# 24/24 [==============================] - 4s 148ms/step - loss: 0.2735 - val_loss: 0.4327
# Epoch 96/150
# 24/24 [==============================] - 4s 168ms/step - loss: 0.2679 - val_loss: 0.4332
# Epoch 97/150
# 24/24 [==============================] - 3s 145ms/step - loss: 0.2660 - val_loss: 0.4311
# Epoch 98/150
# 24/24 [==============================] - 4s 163ms/step - loss: 0.2638 - val_loss: 0.4309
# Epoch 99/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.2621 - val_loss: 0.4310
# Epoch 100/150
# 24/24 [==============================] - 4s 177ms/step - loss: 0.2598 - val_loss: 0.4303
# Epoch 101/150
# 24/24 [==============================] - 4s 149ms/step - loss: 0.2577 - val_loss: 0.4308
# Epoch 102/150
# 24/24 [==============================] - 3s 146ms/step - loss: 0.2542 - val_loss: 0.4282
# Epoch 103/150
# 24/24 [==============================] - 4s 154ms/step - loss: 0.2528 - val_loss: 0.4310
# Epoch 104/150
# 24/24 [==============================] - 4s 172ms/step - loss: 0.2505 - val_loss: 0.4277
# Epoch 105/150
# 24/24 [==============================] - 3s 142ms/step - loss: 0.2512 - val_loss: 0.4296
# Epoch 106/150
# 24/24 [==============================] - 3s 146ms/step - loss: 0.2465 - val_loss: 0.4270
# Epoch 107/150
# 24/24 [==============================] - 4s 154ms/step - loss: 0.2459 - val_loss: 0.4257
# Epoch 108/150
# 24/24 [==============================] - 4s 150ms/step - loss: 0.2421 - val_loss: 0.4295
# Epoch 109/150
# 24/24 [==============================] - 4s 147ms/step - loss: 0.2416 - val_loss: 0.4255
# Epoch 110/150
# 24/24 [==============================] - 4s 153ms/step - loss: 0.2400 - val_loss: 0.4245
# Epoch 111/150
# 24/24 [==============================] - 4s 151ms/step - loss: 0.2367 - val_loss: 0.4280
# Epoch 112/150
# 24/24 [==============================] - 4s 169ms/step - loss: 0.2361 - val_loss: 0.4271
# Epoch 113/150
# 24/24 [==============================] - 4s 165ms/step - loss: 0.2337 - val_loss: 0.4260
# Epoch 114/150
# 24/24 [==============================] - 4s 157ms/step - loss: 0.2326 - val_loss: 0.4273
# Epoch 115/150
# 24/24 [==============================] - 4s 148ms/step - loss: 0.2293 - val_loss: 0.4249
# Epoch 116/150
# 24/24 [==============================] - 4s 153ms/step - loss: 0.2283 - val_loss: 0.4282
# Epoch 117/150
# 24/24 [==============================] - 4s 147ms/step - loss: 0.2291 - val_loss: 0.4267
# Epoch 118/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.2255 - val_loss: 0.4245
# Epoch 119/150
# 24/24 [==============================] - 4s 163ms/step - loss: 0.2237 - val_loss: 0.4292
# Epoch 120/150
# 24/24 [==============================] - 4s 147ms/step - loss: 0.2241 - val_loss: 0.4222
# Epoch 121/150
# 24/24 [==============================] - 4s 146ms/step - loss: 0.2213 - val_loss: 0.4259
# Epoch 122/150
# 24/24 [==============================] - 3s 143ms/step - loss: 0.2189 - val_loss: 0.4232
# Epoch 123/150
# 24/24 [==============================] - 4s 159ms/step - loss: 0.2185 - val_loss: 0.4238
# Epoch 124/150
# 24/24 [==============================] - 3s 144ms/step - loss: 0.2143 - val_loss: 0.4254
# Epoch 125/150
# 24/24 [==============================] - 4s 151ms/step - loss: 0.2139 - val_loss: 0.4242
# Epoch 126/150
# 24/24 [==============================] - 3s 143ms/step - loss: 0.2127 - val_loss: 0.4218
# Epoch 127/150
# 24/24 [==============================] - 4s 147ms/step - loss: 0.2107 - val_loss: 0.4295
# Epoch 128/150
# 24/24 [==============================] - 3s 145ms/step - loss: 0.2116 - val_loss: 0.4226
# Epoch 129/150
# 24/24 [==============================] - 3s 141ms/step - loss: 0.2098 - val_loss: 0.4231
# Epoch 130/150
# 24/24 [==============================] - 4s 153ms/step - loss: 0.2070 - val_loss: 0.4260
# Epoch 131/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.2067 - val_loss: 0.4247
# Epoch 132/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.2052 - val_loss: 0.4215
# Epoch 133/150
# 24/24 [==============================] - 3s 141ms/step - loss: 0.2038 - val_loss: 0.4280
# Epoch 134/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.2002 - val_loss: 0.4222
# Epoch 135/150
# 24/24 [==============================] - 3s 143ms/step - loss: 0.2021 - val_loss: 0.4276
# Epoch 136/150
# 24/24 [==============================] - 4s 148ms/step - loss: 0.1997 - val_loss: 0.4235
# Epoch 137/150
# 24/24 [==============================] - 4s 154ms/step - loss: 0.1993 - val_loss: 0.4276
# Epoch 138/150
# 24/24 [==============================] - 4s 148ms/step - loss: 0.1952 - val_loss: 0.4210
# Epoch 139/150
# 24/24 [==============================] - 5s 209ms/step - loss: 0.1964 - val_loss: 0.4229
# Epoch 140/150
# 24/24 [==============================] - 5s 210ms/step - loss: 0.1945 - val_loss: 0.4232
# Epoch 141/150
# 24/24 [==============================] - 7s 307ms/step - loss: 0.1913 - val_loss: 0.4319
# Epoch 142/150
# 24/24 [==============================] - 4s 153ms/step - loss: 0.1933 - val_loss: 0.4231
# Epoch 143/150
# 24/24 [==============================] - 3s 146ms/step - loss: 0.1927 - val_loss: 0.4287
# Epoch 144/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.1896 - val_loss: 0.4213
# Epoch 145/150
# 24/24 [==============================] - 4s 152ms/step - loss: 0.1885 - val_loss: 0.4295
# Epoch 146/150
# 24/24 [==============================] - 3s 144ms/step - loss: 0.1857 - val_loss: 0.4284
# Epoch 147/150
# 24/24 [==============================] - 3s 141ms/step - loss: 0.1862 - val_loss: 0.4271
# Epoch 148/150
# 24/24 [==============================] - 4s 147ms/step - loss: 0.1858 - val_loss: 0.4215
# Epoch 149/150
# 24/24 [==============================] - 3s 145ms/step - loss: 0.1846 - val_loss: 0.4305
# Epoch 150/150
# 24/24 [==============================] - 4s 150ms/step - loss: 0.1826 - val_loss: 0.4268

# %%
ynew = model.predict([val_q1_seq, val_q2_seq])

# %%
dff2=pd.DataFrame()
dff2['Actual']=y_val
dff2['Predicted']=ynew
dff2
# Out:
#      Actual  Predicted
# 0       1.0   1.035084
# 1       1.0   1.130089
# 2       1.0   1.098251
# 3       1.0   1.135204
# 4       2.0   1.020414
# ..      ...        ...
# 642     1.0   0.949275
# 643     2.0   0.845993
# 644     1.0   0.808706
# 645     1.0   1.721539
# 646     2.0   2.296543
#
# [647 rows x 2 columns]

# %%
metrics.mean_absolute_error(y_val,ynew)
# Out:
# 0.43885621201632746

# %%
plt.hist(ynew)
plt.show()

# %%
plt.hist(y_val)
plt.show()
